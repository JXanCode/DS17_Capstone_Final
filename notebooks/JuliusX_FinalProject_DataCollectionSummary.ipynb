# %%
import requests
import numpy as np
import pandas as pd
import json

import datetime

import yfinance as yf
from fredapi import Fred 

from bs4 import BeautifulSoup
import re

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data for Final Project:
#
# I collected my data from 3 sources: [FRED database](https://fred.stlouisfed.org/), [Office of Financial Research](https://www.financialresearch.gov/financial-stress-index/), and [Yahoo Finance](https://finance.yahoo.com/).
#
# The steps to collect the data was different between the 3 sources. Once I cleaned the data from each source, I merged the data into one dataframe and saved this as a CSV (all_data.csv).
#
# Not all of the features were available on a daily timeframe, so I used forward fill (ffill) to repeat values that only exist on a weekly, monthly, or quarterly timeframe.
#
# Most features that are not updated on a daily basis have a lag between observation date and the actual date an observation is published. To avoid any forward-looking bias, I synchronized the values between all features based on publishing date and labeled this is as 'model_date'.
#
# Although my dataset is now on a daily timeframe, I will isolate my observations to one day of the week (such as Friday) to reduce noise in the data. The dates include weekends even though most values are only published on weekdays. The reason for keeping weekends is because when I switch to a weekly basis, I want the time difference between observations to always be the same and not be affected by holidays. In the case of a holiday, the previous day's values are assigned to the holiday.
#
# Now that all the data is collected and cleaned, I can start to analyze and conduct feature selection.

# %%
all_data = pd.read_csv('all_data_Apr28.csv')
all_data = all_data.set_index('model_date')
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7752 entries, 2003-02-07 to 2024-04-28
# Data columns (total 60 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   AE                    7752 non-null   float64
#  1   ASPUS                 7752 non-null   float64
#  2   BAMLC0A0CM            7752 non-null   float64
#  3   BAMLEMCBPIOAS         7752 non-null   float64
#  4   BAMLEMRACRPIASIAOAS   7752 non-null   float64
#  5   BAMLH0A0HYM2          7752 non-null   float64
#  6   BAMLH0A0HYM2EY        7752 non-null   float64
#  7   BAMLHE00EHYIOAS       7752 non-null   float64
#  8   CIVPART               7752 non-null   float64
#  9   CORESTICKM159SFRBATL  7752 non-null   float64
#  10  CPIAUCSL              7752 non-null   float64
#  11  CPILFESL              7752 non-null   float64
#  12  CSUSHPINSA            7752 non-null   float64
#  13  Credit                7752 non-null   float64
#  14  DAAA                  7752 non-null   float64
#  15  DFF                   7752 non-null   float64
#  16  DFII10                7752 non-null   float64
#  17  DGS10                 7752 non-null   float64
#  18  DGS1MO                7752 non-null   float64
#  19  DGS2                  7752 non-null   float64
#  20  DGS20                 7752 non-null   float64
#  21  DGS3                  7752 non-null   float64
#  22  DGS30                 7752 non-null   float64
#  23  DGS3MO                7752 non-null   float64
#  24  DGS5                  7752 non-null   float64
#  25  DGS6MO                7752 non-null   float64
#  26  DGS7                  7752 non-null   float64
#  27  DRCCLACBS             7752 non-null   float64
#  28  DTB3                  7752 non-null   float64
#  29  DX=F                  7752 non-null   float64
#  30  EM                    7752 non-null   float64
#  31  Equity_Valuation      7752 non-null   float64
#  32  Flight_to_Safety      7752 non-null   float64
#  33  Funding               7752 non-null   float64
#  34  GC=F                  7752 non-null   float64
#  35  GDP                   7752 non-null   float64
#  36  GDPC1                 7752 non-null   float64
#  37  GFDEBTN               7752 non-null   float64
#  38  GFDEGDQ188S           7752 non-null   float64
#  39  ICSA                  7752 non-null   float64
#  40  JPY=X                 7752 non-null   float64
#  41  M1SL                  7752 non-null   float64
#  42  M2SL                  7752 non-null   float64
#  43  M2V                   7752 non-null   float64
#  44  MORTGAGE15US          7752 non-null   float64
#  45  MORTGAGE30US          7752 non-null   float64
#  46  MSPUS                 7752 non-null   float64
#  47  OFRFSI                7752 non-null   float64
#  48  PAYEMS                7752 non-null   float64
#  49  PCE                   7752 non-null   float64
#  50  PSAVERT               7752 non-null   float64
#  51  RRPONTSYD             7752 non-null   float64
#  52  T10YIE                7752 non-null   float64
#  53  T5YIE                 7752 non-null   float64
#  54  UNRATE                7752 non-null   float64
#  55  US                    7752 non-null   float64
#  56  Volatility            7752 non-null   float64
#  57  WALCL                 7752 non-null   float64
#  58  ^GSPC                 7752 non-null   float64
#  59  ^VIX                  7752 non-null   float64
# dtypes: float64(60)
# memory usage: 3.6+ MB

# %%
all_data.shape
# Out:
# (7752, 60)

# %%
all_data.describe()
# Out:
#                 AE          ASPUS   BAMLC0A0CM  BAMLEMCBPIOAS  \
# count  7752.000000    7752.000000  7752.000000    7752.000000
# mean     -0.145258  339923.826109     1.556046       3.394034
# std       2.163126   76858.119036     0.898017       1.752037
# min      -2.691000  232500.000000     0.790000       1.440000
# 25%      -1.515000  278000.000000     1.030000       2.570000
# 50%      -0.755000  322100.000000     1.330000       3.110000
# 75%       0.547000  377900.000000     1.660000       3.810000
# max      14.057000  542900.000000     6.560000      13.860000
#
#        BAMLEMRACRPIASIAOAS  BAMLH0A0HYM2  BAMLH0A0HYM2EY  BAMLHE00EHYIOAS  \
# count          7752.000000   7752.000000     7752.000000      7752.000000
# mean              2.594453      5.186489        7.683550         5.167094
# std               1.312416      2.586461        2.579344         3.264253
# min               1.010000      2.410000        3.920000         1.780000
# 25%               1.790000      3.680000        6.140000         3.430000
# 50%               2.460000      4.450000        7.410000         4.170000
# 75%               2.940000      5.920000        8.400000         5.660000
# max               9.790000     21.820000       23.260000        23.260000
#
#            CIVPART  CORESTICKM159SFRBATL  ...      PSAVERT    RRPONTSYD  \
# count  7752.000000           7752.000000  ...  7752.000000  7752.000000
# mean     63.938287              2.563584  ...     4.557830   244.704243
# std       1.603443              1.134876  ...     4.243106   579.910414
# min      60.200000              0.660000  ...    -1.700000     0.000000
# 25%      62.700000              2.059257  ...     2.600000     1.430000
# 50%      63.300000              2.340000  ...     4.200000     3.500000
# 75%      65.900000              2.670000  ...     5.600000   102.741000
# max      66.600000              6.606693  ...    33.000000  2553.716000
#
#             T10YIE        T5YIE       UNRATE           US   Volatility  \
# count  7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean      2.087681     1.924354     5.874497    -0.140759    -0.402171
# std       0.407139     0.579814     2.044059     1.824247     1.507751
# min       0.040000    -2.240000     3.400000    -2.008000    -2.597000
# 25%       1.830000     1.610000     4.400000    -1.207250    -1.400000
# 50%       2.190000     1.950000     5.300000    -0.612500    -0.668000
# 75%       2.370000     2.320000     7.200000     0.131000     0.205000
# max       3.020000     3.590000    14.700000    13.279000     9.787000
#
#               WALCL        ^GSPC         ^VIX
# count  7.752000e+03  7752.000000  7752.000000
# mean   3.701084e+06  2134.098025    19.093411
# std    2.530878e+06  1138.917476     8.574020
# min    7.142920e+05   676.530029     9.140000
# 25%    8.993175e+05  1237.910034    13.420000
#
# [10 rows x 60 columns]

# %%
all_data.tail(10)
# Out:
#                AE     ASPUS  BAMLC0A0CM  BAMLEMCBPIOAS  BAMLEMRACRPIASIAOAS  \
# model_date
# 2024-04-19 -0.297  492300.0        0.94           1.95                 1.31
# 2024-04-20 -0.407  492300.0        0.94           1.95                 1.31
# 2024-04-21 -0.263  492300.0        0.94           1.95                 1.31
# 2024-04-22 -0.263  492300.0        0.93           1.95                 1.32
# 2024-04-23 -0.263  492300.0        0.92           1.94                 1.32
# 2024-04-24 -0.422  492300.0        0.92           1.93                 1.31
# 2024-04-25 -0.520  492300.0        0.92           1.92                 1.30
# 2024-04-26 -0.545  492300.0        0.92           1.92                 1.30
# 2024-04-27 -0.545  492300.0        0.92           1.92                 1.30
# 2024-04-28 -0.545  492300.0        0.92           1.92                 1.30
#
#             BAMLH0A0HYM2  BAMLH0A0HYM2EY  BAMLHE00EHYIOAS  CIVPART  \
# model_date
# 2024-04-19          3.37            8.10             3.66     62.7
# 2024-04-20          3.37            8.10             3.66     62.7
# 2024-04-21          3.37            8.10             3.66     62.7
# 2024-04-22          3.29            8.01             3.65     62.7
# 2024-04-23          3.20            7.88             3.59     62.7
# 2024-04-24          3.19            7.90             3.55     62.7
# 2024-04-25          3.24            8.00             3.57     62.7
# 2024-04-26          3.24            8.00             3.57     62.7
# 2024-04-27          3.24            8.00             3.57     62.7
# 2024-04-28          3.24            8.00             3.57     62.7
#
#             CORESTICKM159SFRBATL  ...  PSAVERT  RRPONTSYD  T10YIE  T5YIE  \
# model_date                        ...
# 2024-04-19              4.509212  ...      3.6    397.234    2.41   2.44
# 2024-04-20              4.509212  ...      3.6    397.234    2.41   2.44
# 2024-04-21              4.509212  ...      3.6    397.234    2.41   2.44
# 2024-04-22              4.509212  ...      3.6    409.816    2.41   2.45
# 2024-04-23              4.509212  ...      3.6    435.880    2.41   2.44
# 2024-04-24              4.509212  ...      3.6    441.215    2.41   2.42
# 2024-04-25              4.509212  ...      3.6    443.928    2.42   2.43
# 2024-04-26              4.509212  ...      3.2    464.912    2.43   2.44
# 2024-04-27              4.509212  ...      3.2    464.912    2.43   2.44
# 2024-04-28              4.509212  ...      3.2    464.912    2.43   2.44
#
#             UNRATE     US  Volatility      WALCL        ^GSPC       ^VIX
# model_date
# 2024-04-19     3.8 -0.861      -0.179  7405506.0  4967.229980  18.709999
# 2024-04-20     3.8 -0.887      -0.301  7405506.0  4967.229980  18.709999
# 2024-04-21     3.8 -0.857      -0.137  7405506.0  4967.229980  18.709999
# 2024-04-22     3.8 -0.857      -0.137  7405506.0  5010.600098  16.940001
# 2024-04-23     3.8 -0.857      -0.137  7405506.0  5070.549805  15.690000
# 2024-04-24     3.8 -0.959      -0.359  7405506.0  5071.629883  15.970000
# 2024-04-25     3.8 -1.031      -0.493  7402434.0  5048.419922  15.370000
# 2024-04-26     3.8 -1.005      -0.489  7402434.0  5099.959961  15.030000
# 2024-04-27     3.8 -1.005      -0.489  7402434.0  5099.959961  15.030000
# 2024-04-28     3.8 -1.005      -0.489  7402434.0  5099.959961  15.030000
#
# [10 rows x 60 columns]
